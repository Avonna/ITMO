# %% [markdown]
# <a href="https://colab.research.google.com/github/Avonna/ITMO/blob/master/%D0%9A%205%20%D0%BD%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%20%D0%98%D0%A2%D0%9C%D0%9E%20%D0%BF%D0%BE%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%BA%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# подключение библиотек
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
# чтение данных
df = pd.read_csv("/content/asset-v1_ITMOUniversity+DATANFST2035+cifru_2035+type@asset+block@FlightDelays_small_no_ID (1).csv")

# %%
# Отбор данных по перевозчику UA и группировка по месяцу
temp = df.loc[df['Carrier'] == 'UA'].groupby(['Month']).count()

# %%
# Отделяем данные о количестве совершенных вылетов
FL = list(temp['Year'])

# %%
# Создаем подписи для оси Х
x = ['Апрель', 'Май', 'Июнь', 'Июль', 'Август', 'Сентябрь', 'Октябрь']
x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, FL, color='blue', width=0.5)
plt.xlabel("Месяц")
plt.ylabel("Количество совершенных рейсов")

plt.xticks(x_pos, x)

plt.show()
